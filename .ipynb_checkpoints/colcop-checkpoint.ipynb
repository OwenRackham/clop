# %%
from colorthief import ColorThief
color_thief = ColorThief('face.jpg')
# get the dominant color
dominant_color = color_thief.get_color(quality=1)
# build a color palette
palette = color_thief.get_palette(color_count=10)
palette
# Out:
# [(102, 52, 30),
#  (161, 136, 124),
#  (50, 32, 25),
#  (108, 127, 140),
#  (154, 184, 203),
#  (45, 81, 120),
#  (200, 170, 141),
#  (149, 112, 80),
#  (63, 118, 168),
#  (248, 222, 61),
#  (104, 106, 80),
#  (66, 112, 131),
#  (226, 202, 176),
#  (159, 79, 26),
#  (57, 83, 80),
#  (103, 86, 98),
#  (235, 143, 51),
#  (215, 74, 26),
#  (32, 53, 84),
#  (184, 111, 12),
#  (193, 174, 174),
#  (243, 236, 226),
#  (177, 206, 220),
#  (107, 79, 74),
#  (199, 132, 67),
#  (222, 228, 235),
#  (43, 45, 57),
#  (7, 24, 31),
#  (57, 62, 49),
#  (125, 167, 179),
#  (247, 184, 136),
#  (118, 168, 217),
#  (153, 165, 145),
#  (232, 138, 120),
#  (63, 175, 242),
#  (250, 235, 131),
#  (119, 86, 39),
#  (112, 150, 184),
#  (135, 64, 23),
#  (113, 218, 237),
#  (100, 14, 15),
#  (200, 205, 200),
#  (188, 212, 222),
#  (212, 223, 228),
#  (200, 218, 224),
#  (214, 247, 245),
#  (164, 153, 87),
#  (206, 225, 244),
#  (203, 228, 228),
#  (200, 218, 236),
#  (200, 215, 212),
#  (210, 236, 234),
#  (156, 237, 246),
#  (84, 92, 180),
#  (168, 144, 218),
#  (192, 194, 215),
#  (200, 204, 215),
#  (224, 219, 212),
#  (222, 204, 220)]

# %%
from PIL import Image
import numpy

def closest_col( palette, col ):
    pal_length = len(palette)
    close_col = palette[0]
    close_dist = numpy.linalg.norm(numpy.array(col)-numpy.array(close_col))
    for x in range(1, pal_length):
        current_col = palette[x]
        current_dist = numpy.linalg.norm(numpy.array(col)-numpy.array(current_col))
        if current_dist < close_dist:
            close_col = current_col
    return close_col

img = Image.open('face.jpg')
pix = img.load()
dims = img.size

for x in range(1, dims[0]):
    for y in range(1, dims[1]):
        pix[x,y] = closest_col(palette,pix[x,y])
# Out:
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# <ipython-input-9-cecc96f8954b> in <module>()
#      19 for x in range(1, dims[0]):
#      20     for y in range(1, dims[1]):
# ---> 21         pix[x,y] = (numpy.array(pix[x,y]) + numpy.array(closest_col(palette,pix[x,y])))/2
#      22
#      23
#
# SystemError: new style getargs format but argument is not a tuple

# %%
print(img.size)
# Out:
# (1200, 668)

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x668 at 0x104373048>
